# %% [markdown]
# <a href="https://colab.research.google.com/github/arpitad001/AlgoLab/blob/main/DSAPython_Arpita.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name="Arpita"

# %%
age=23

# %%
print(id(age))  # to find the address we use id
# Out:
# 11655080

# %%
x=23
print(id(x))
# Out:
# 11655080

# %%
# Variable are case sensitive
a=21
A=22
print(a)
print(A)
# Out:
# 21
# 22

# %%
help()
# Out:
# Welcome to Python 3.12's help utility! If this is your first time using
# Python, you should definitely check out the tutorial at
# https://docs.python.org/3.12/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To get a list of available
# modules, keywords, symbols, or topics, enter "modules", "keywords",
# "symbols", or "topics".
#
# Each module also comes with a one-line summary of what it does; to list
# the modules whose name or summary contain a given string such as "spam",
# enter "modules spam".
#
# To quit this help utility and return to the interpreter,
# enter "q" or "quit".
#
# help> keywords
#
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# ...

# %%
# This is a commented line ( single line comments)
# Out:
# hello

# %%
#Multi line comment
''' This is the first line of comment
This is the second line of comment
This is the third line of comment'''
# Out:
# ' This is the first line of comment\nThis is the second line of comment\nThis is the third line of comment'

# %%
# IO
input()
# Out:
# arpita
# 'arpita'

# %%
name=input()
print(name)
# Out:
# Arpita Mall
# Arpita Mall

# %%
age=input("please enter your age in years")
# Out:
# please enter your age in years23

# %%
print(age)
# Out:
# 23

# %%
# Output
print("I am Arpita")
# Out:
# I am Arpita

# %%
name="Arpita"
age=23
print("Hello , My name is", name, "and my age is ", age)
# Out:
# Hello , My name is Arpita and my age is  23

# %%
# Support for the formatted string
print(f"My name is {name} and age is {age}")
# Out:
# My name is Arpita and age is 23

# %%
x=2
y=3
z=5
print(x,y,z, sep="$")
# Out:
# 2$3$5
