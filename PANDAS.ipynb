# %% [markdown]
# <a href="https://colab.research.google.com/github/arpitad001/AlgoLab/blob/main/PANDAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Data Analysis Using Pandas
#Data structure with series without indexing
import pandas as pd
s=pd.Series([98,48,54,66,87,76,44])

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
print(s)
# Out:
# 0    98
# 1    48
# 2    54
# 3    66
# 4    87
# 5    76
# 6    44
# dtype: int64

# %%
#Data structure with series with indexing
s1=s=pd.Series([98,48,54,66,87,76,44], index=["Ram","shyam","Arrpita","Rohan","Sohan","Sita","Gita"])

# %%
s1
# Out:
# Ram        98
# shyam      48
# Arrpita    54
# Rohan      66
# Sohan      87
# Sita       76
# Gita       44
# dtype: int64

# %%
s1["Arrpita"]
# Out:
# np.int64(54)

# %%
#Data structure with DataFrame - 2D Labeled
import pandas as pd
data={"Name":["Deevyansh","shyam","Arrpita","Rohan"],
      "Marks":[98,48,54,66],
      "City":["Vrindavan","Pune","Mau","Varanasi"]}

# %%
df=pd.DataFrame(data)
df
# Out:
#         Name  Marks       City
# 0  Deevyansh     98  Vrindavan
# 1      shyam     48       Pune
# 2    Arrpita     54        Mau
# 3      Rohan     66   Varanasi

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df.columns
# Out:
# Index(['Name', 'Marks', 'City'], dtype='object')

# %%
# CREATING DATA FRAMES
# 1. From Python Lists
import pandas as pd
data=[['Arpita',34],['Devvy',55],['Dishu',77]]
data
# Out:
# [['Arpita', 34], ['Devvy', 55], ['Dishu', 77]]

# %%
pd.DataFrame(data,columns=["Name","Marks"])
# Out:
#      Name  Marks
# 0  Arpita     34
# 1   Devvy     55
# 2   Dishu     77

# %%
# 2. From dictionary to lists
data={"a":[1,2,3],"b":[4,5,6],"c":[7,8,9]}
data
# Out:
# {'a': [1, 2, 3], 'b': [4, 5, 6], 'c': [7, 8, 9]}

# %%
df=pd.DataFrame(data)
df
# Out:
#    a  b  c
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
# 3. From NumPy arrays
import numpy as np
arr=np.array([[3,4,10], [6,7,11], [5,9,12]])
df=pd.DataFrame(arr,columns=["A","B","C"])
df
# Out:
#    A  B   C
# 0  3  4  10
# 1  6  7  11
# 2  5  9  12

# %%
# 4. From CSV Files
           # df = pd.read_csv("data.csv")
# 5. From Excel Files
          # df = pd.read_excel("data.xlsx")
# 6. From JSON
         # df = pd.read_json("data.json")
# 7. From SQL Databases
        #import sqlite3
        #conn = sqlite3.connect("mydb.sqlite")
        #df = pd.read_sql("SELECT * FROM users", conn
# 8. From the Web
        # url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv"
        #df = pd.read_csv(url)

# %%
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv"
df = pd.read_csv(url)
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df.shape # rows,colums
# Out:
# (244, 7)

# %%
import pandas as pd
df=pd.read_csv("dataset.csv.csv")
df
# Out:
#     Customer_ID  Age Gender  Amount_Spent  Visits
# 0          1001   25      M          7960      25
# 1          1002   51      M          4004       7
# 2          1003   52      M         17713      20
# 3          1004   49      F          4640       4
# 4          1005   41      M          2341      27
# ..          ...  ...    ...           ...     ...
# 95         1096   29      M          5805      17
# 96         1097   40      M          1806      18
# 97         1098   59      F          9202       8
# 98         1099   39      M          2868      13
# 99         1100   38      M         15561      29
#
# [100 rows x 5 columns]

# %%
# SELECTING COLUMNS
df['Customer_ID'][3]
# Out:
# np.int64(1004)

# %%
type(df['Customer_ID'])
# Out:
# pandas.core.series.Series

# %%
df[['Customer_ID','Gender']]
# Out:
#     Customer_ID Gender
# 0          1001      M
# 1          1002      M
# 2          1003      M
# 3          1004      F
# 4          1005      M
# ..          ...    ...
# 95         1096      M
# 96         1097      M
# 97         1098      F
# 98         1099      M
# 99         1100      M
#
# [100 rows x 2 columns]

# %%
# SELECTING ROWS BY INDEX
df.loc[1]  # by row level
# Out:
# Customer_ID     1002
# Age               51
# Gender             M
# Amount_Spent    4004
# Visits             7
# Name: 1, dtype: object

# %%
df.iloc[1]   # by index
# Out:
# Customer_ID     1002
# Age               51
# Gender             M
# Amount_Spent    4004
# Visits             7
# Name: 1, dtype: object

# %%
# SELECT SPECIFIC ROWS AND COLUMNS
df.loc[2,'Amount_Spent']
# Out:
# np.int64(17713)

# %%
df.iloc[2,3]
# Out:
# np.int64(17713)

# %%
df.loc[0:2,['Customer_ID','Age','Gender']]
# Out:
#    Customer_ID  Age Gender
# 0         1001   25      M
# 1         1002   51      M
# 2         1003   52      M

# %%
df.iloc[0:3,0:3]
# Out:
#    Customer_ID  Age Gender
# 0         1001   25      M
# 1         1002   51      M
# 2         1003   52      M

# %%
# for accessing particular element
df.at[0,"Customer_ID"]
# Out:
# np.int64(1001)

# %%
df[df['Visits']>27]    # FILTERING
# Out:
#     Customer_ID  Age Gender  Amount_Spent  Visits
# 7          1008   63      F          6895      29
# 35         1036   28      F          5497      29
# 48         1049   61      F         18304      29
# 61         1062   67      M          4810      28
# 62         1063   68      M          8206      29
# 78         1079   62      M          3050      28
# 89         1090   55      F         10155      28
# 92         1093   54      F          2828      28
# 99         1100   38      M         15561      29

# %%
df[(df['Visits']>27) & (df['Amount_Spent']>8206)]
# Out:
#     Customer_ID  Age Gender  Amount_Spent  Visits
# 48         1049   61      F         18304      29
# 89         1090   55      F         10155      28
# 99         1100   38      M         15561      29

# %%
df.query("Visits > 28 and Amount_Spent > 1830")
# Out:
#     Customer_ID  Age Gender  Amount_Spent  Visits
# 7          1008   63      F          6895      29
# 35         1036   28      F          5497      29
# 48         1049   61      F         18304      29
# 62         1063   68      M          8206      29
# 99         1100   38      M         15561      29

# %%
df2=df[['Customer_ID','Visits']].copy()
df2
# Out:
#     Customer_ID  Visits
# 0          1001      25
# 1          1002       7
# 2          1003      20
# 3          1004       4
# 4          1005      27
# ..          ...     ...
# 95         1096      17
# 96         1097      18
# 97         1098       8
# 98         1099      13
# 99         1100      29
#
# [100 rows x 2 columns]

# %%
df2.loc[0,"Customer_ID"]=1234
df2
# Out:
#     Customer_ID  Visits  (Customer_ID, 0)
# 0          1234      25              1234
# 1          1002       7              1234
# 2          1003      20              1234
# 3          1004       4              1234
# 4          1005      27              1234
# ..          ...     ...               ...
# 95         1096      17              1234
# 96         1097      18              1234
# 97         1098       8              1234
# 98         1099      13              1234
# 99         1100      29              1234
#
# [100 rows x 3 columns]

# %%
import pandas as pd
df=pd.read_csv("dataset.csv")
df
# Out:
#     Customer_ID  Age Gender  Amount_Spent  Visits
# 0        1001.0   25      M        7960.0    25.0
# 1        1002.0   51      M        4004.0     NaN
# 2        1003.0   52      M       17713.0    20.0
# 3        1004.0   49      F        4640.0     4.0
# 4        1005.0   41      M        2341.0    27.0
# ..          ...  ...    ...           ...     ...
# 95       1096.0   29      M        5805.0    17.0
# 96       1097.0   40      M        1806.0    18.0
# 97       1098.0   59      F        9202.0     8.0
# 98       1099.0   39      M        2868.0    13.0
# 99       1100.0   38      M       15561.0    29.0
#
# [100 rows x 5 columns]

# %%
df.isnull()
# Out:
#     Customer_ID    Age  Gender  Amount_Spent  Visits
# 0         False  False   False         False   False
# 1         False  False   False         False    True
# 2         False  False   False         False   False
# 3         False  False   False         False   False
# 4         False  False   False         False   False
# ..          ...    ...     ...           ...     ...
# 95        False  False   False         False   False
# 96        False  False   False         False   False
# 97        False  False   False         False   False
# 98        False  False   False         False   False
# 99        False  False   False         False   False
#
# [100 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# Customer_ID     1
# Age             0
# Gender          1
# Amount_Spent    1
# Visits          2
# dtype: int64

# %%
df.dropna()
# Out:
#     Customer_ID  Age Gender  Amount_Spent  Visits
# 0        1001.0   25      M        7960.0    25.0
# 2        1003.0   52      M       17713.0    20.0
# 3        1004.0   49      F        4640.0     4.0
# 4        1005.0   41      M        2341.0    27.0
# 6        1007.0   49      F        1338.0    20.0
# ..          ...  ...    ...           ...     ...
# 95       1096.0   29      M        5805.0    17.0
# 96       1097.0   40      M        1806.0    18.0
# 97       1098.0   59      F        9202.0     8.0
# 98       1099.0   39      M        2868.0    13.0
# 99       1100.0   38      M       15561.0    29.0
#
# [95 rows x 5 columns]

# %%
df.dropna(axis=1)
# Out:
#     Age
# 0    25
# 1    51
# 2    52
# 3    49
# 4    41
# ..  ...
# 95   29
# 96   40
# 97   59
# 98   39
# 99   38
#
# [100 rows x 1 columns]

# %%
df.fillna(0)
# Out:
#     Customer_ID  Age Gender  Amount_Spent  Visits
# 0        1001.0   25      M        7960.0    25.0
# 1        1002.0   51      M        4004.0     0.0
# 2        1003.0   52      M       17713.0    20.0
# 3        1004.0   49      F        4640.0     4.0
# 4        1005.0   41      M        2341.0    27.0
# ..          ...  ...    ...           ...     ...
# 95       1096.0   29      M        5805.0    17.0
# 96       1097.0   40      M        1806.0    18.0
# 97       1098.0   59      F        9202.0     8.0
# 98       1099.0   39      M        2868.0    13.0
# 99       1100.0   38      M       15561.0    29.0
#
# [100 rows x 5 columns]

# %%
df["Visits"].fillna(df["Visits"].mean())
# Out:
# 0     25.000000
# 1     15.204082
# 2     20.000000
# 3      4.000000
# 4     27.000000
#         ...
# 95    17.000000
# 96    18.000000
# 97     8.000000
# 98    13.000000
# 99    29.000000
# Name: Visits, Length: 100, dtype: float64

# %%
df.ffill()
# Out:
#     Customer_ID  Age Gender  Amount_Spent  Visits
# 0        1001.0   25      M        7960.0    25.0
# 1        1002.0   51      M        4004.0    25.0
# 2        1003.0   52      M       17713.0    20.0
# 3        1004.0   49      F        4640.0     4.0
# 4        1005.0   41      M        2341.0    27.0
# ..          ...  ...    ...           ...     ...
# 95       1096.0   29      M        5805.0    17.0
# 96       1097.0   40      M        1806.0    18.0
# 97       1098.0   59      F        9202.0     8.0
# 98       1099.0   39      M        2868.0    13.0
# 99       1100.0   38      M       15561.0    29.0
#
# [100 rows x 5 columns]

# %%
df.bfill()
# Out:
#     Customer_ID  Age Gender  Amount_Spent  Visits
# 0        1001.0   25      M        7960.0    25.0
# 1        1002.0   51      M        4004.0    20.0
# 2        1003.0   52      M       17713.0    20.0
# 3        1004.0   49      F        4640.0     4.0
# 4        1005.0   41      M        2341.0    27.0
# ..          ...  ...    ...           ...     ...
# 95       1096.0   29      M        5805.0    17.0
# 96       1097.0   40      M        1806.0    18.0
# 97       1098.0   59      F        9202.0     8.0
# 98       1099.0   39      M        2868.0    13.0
# 99       1100.0   38      M       15561.0    29.0
#
# [100 rows x 5 columns]

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Length: 100, dtype: bool

# %%
df.drop_duplicates()  # data which dont have duplicates
# Out:
#     Customer_ID  Age Gender  Amount_Spent  Visits
# 0        1001.0   25      M        7960.0    25.0
# 1        1002.0   51      M        4004.0     NaN
# 2        1003.0   52      M       17713.0    20.0
# 3        1004.0   49      F        4640.0     4.0
# 4        1005.0   41      M        2341.0    27.0
# ..          ...  ...    ...           ...     ...
# 95       1096.0   29      M        5805.0    17.0
# 96       1097.0   40      M        1806.0    18.0
# 97       1098.0   59      F        9202.0     8.0
# 98       1099.0   39      M        2868.0    13.0
# 99       1100.0   38      M       15561.0    29.0
#
# [100 rows x 5 columns]

# %%
# STRING OPERATIONS WITH .STR
 #    df["Name"].str.lower()   # Converts all names to lowercase.
#     df["City"].str.contains("delhi", case=False)    # Checks if 'delhi' is in the city name, case-insensitive.
#     df["Email"].str.split("@")     # Outputs a pandas Series where each element is a list of strings (the split parts). This is where a Python list comes into play, but the outer object is still a pandas Series.

# %%
df["Age"]=df["Age"].astype(float)
df
# Out:
#     Customer_ID   Age Gender  Amount_Spent  Visits
# 0        1001.0  25.0      M        7960.0    25.0
# 1        1002.0  51.0      M        4004.0     NaN
# 2        1003.0  52.0      M       17713.0    20.0
# 3        1004.0  49.0      F        4640.0     4.0
# 4        1005.0  41.0      M        2341.0    27.0
# ..          ...   ...    ...           ...     ...
# 95       1096.0  29.0      M        5805.0    17.0
# 96       1097.0  40.0      M        1806.0    18.0
# 97       1098.0  59.0      F        9202.0     8.0
# 98       1099.0  39.0      M        2868.0    13.0
# 99       1100.0  38.0      M       15561.0    29.0
#
# [100 rows x 5 columns]

# %%
# TO CONVERT INTO DATE TIMES # df["Date"] = pd.to_datetime(df["Date"])

# %%
df["Age Group"] = df["Age"].apply(lambda x: "Adult" if x >=50 else "Minor")
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-429213551.py in <cell line: 0>()
# ...

# %%
df
# Out:
#     Customer_ID   Age Gender  Amount_Spent  Visits Age Group
# 0        1001.0  25.0    NaN        7960.0    25.0     Minor
# 1        1002.0  51.0    NaN        4004.0     NaN     Adult
# 2        1003.0  52.0    NaN       17713.0    20.0     Adult
# 3        1004.0  49.0    NaN        4640.0     4.0     Minor
# 4        1005.0  41.0    NaN        2341.0    27.0     Minor
# ..          ...   ...    ...           ...     ...       ...
# 95       1096.0  29.0    NaN        5805.0    17.0     Minor
# 96       1097.0  40.0    NaN        1806.0    18.0     Minor
# 97       1098.0  59.0    NaN        9202.0     8.0     Adult
# 98       1099.0  39.0    NaN        2868.0    13.0     Minor
# 99       1100.0  38.0    NaN       15561.0    29.0     Minor
#
# [100 rows x 6 columns]

# %%
gender_map = {"M": "Male", "F": "Female"}
df["Gender"] = df["Gender"].map(gender_map)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Gender'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3563215814.py in <cell line: 0>()
#       1 gender_map = {"M": "Male", "F": "Female"}
# ...
